# %% [markdown]
# In this notebook we provide a small example of our methodology to use deep learning in real time to accelerate GMRES

# %% [markdown]
# We demonstrate our real-time deep-learning methodology using the $2D$ Poisson problem.
#
#
# In particular, we solve a sequence of problems
#
# \begin{align}
# \Delta u = f_i \\
# u |_{ \partial \Omega} = 0
# \end{align}
# where $f_i$ are randomly permuted for every index.
#
#
#
#
#
#
#
# The gist of our idea is that our real-time deep learning methodology wraps around a provided GMRES solver, and over time
# learns an initial guess/left perconditioner that accelerates the rate of convergence of the solver.

# %% [markdown]
# First, we set a number of things such as:
# - Dimension of $N \times N$ grid
# - Default initial guess for GMRES iterations
# - Tolerances for GMRES solver
# - Restarted GMRES restart parameters
# - Total number of "time steps"

# %%
from src_dir import mk_laplace_2d,mk_laplace_2d_Tensor
import numpy as np

# Set dimension of the NxN grid used
dim=20

# Default initial guess used for direct 
# un-preconditioned GMRES is the zero solution
x0=np.squeeze(np.zeros((dim,dim)))
x0Type='Zero Solution 2D'


# Set tolerances for GMRES solver
e1 = 1e-6


# Restarted GMRES parameters
nmax_iter =int(dim/5)
restart   = 150000000000


# Create domain [-1,1]x[-1,1]
DomainL=-1.0
DomainR=1.0

# Define grid values at midpoints of cartesian grid
dx=(DomainR-DomainL)/(dim-1)
x1=np.linspace(DomainL+dx,DomainR-dx,dim)
x2=np.linspace(DomainL+dx,DomainR-dx,dim)
X, Y = np.meshgrid(x1, x2, sparse=False, indexing='ij')
Area=(dx*(dim-1))**2

# Create 2D laplace opertor as
# a stencil opertor for a N-cell 2D grid
# Can be found in linop.py in src_di
A=mk_laplace_2d(dim,dim,dx,bc="dirichlet", xlo=0, xhi=0, ylo=0, yhi=0)
AType='2D Laplacian'


# Total number of steps in simulation
n_steps =2000

# %% [markdown]
# Below, we wrap the simple unprecondition GMRES algorithm implemented in `gmres.py` using a wrapper
# that implements our deep learning methodology. This wrapper contains both the neural network we
# implemented, the training loop of this network, and additional data curration steps to work online
#
# The neural netowrk can be found in `cnn_collectionOnline.py`, and the wrapper can be found in
# `cnn_predictorOnline2D.py`. Stay tuned for a paper the describes our methodology in detail.

# %%
from src_dir import cnn_preconditionerOnline_timed_2D,timer,GMRES

# Note: # Model dimention inputs are not used for the current network in cnn_predictorOnline2D.py (but must be passed into wrapper)
InputDim=dim
OutputDim=dim

# Note: the CNN in cnn_predictorOnline2D.py should be adjusted depending on the grid resolution. Some examples are commented out in that file. 
@timer
@cnn_preconditionerOnline_timed_2D(Area,dx,retrain_freq=1,debug=True,InputDim=InputDim,OutputDim=OutputDim)
def MLGMRES(A, b ,x0, e, nmax_iter,ML_GMRES_Time_list,ProbCount,restart,debug,blist,bnormList,reslist,Err_list,reslist_flat,solIndx,IterErrList):
    return GMRES(A, b, x0, e, nmax_iter,restart, debug)

@timer
def GMRES_timed(A, b, x0, e, nmax_iter,restart,debug):
    return GMRES(A, b, x0, e, nmax_iter,restart, debug)

# %% [markdown]
# To demonstrate the performance of our approach on a series of poisson problems, we  split up our GMRES solver into two a "coarse"
# solve step and a refine step that converge up to tolerances $e_1$ and $e_2$ respectively.  The loop below (that loops for the number of steps set above) essentially has the following structure:
#
# 1. Generate RHS
# 2. Compute GMRES assisted by neural network (MLGMRES) up to tolreance $e_1$
# 3. Compute MLGMRES up to tolerance $e_2$ and collect data. Depending on the retrain frequency and other parameters in our methodology, the collected data is added to the training set and the NN model is retrained
# 4. Compute direct GMRES up to $e_1$
# 5. Compute direct GMRES up to $e_2$
# 6. Write error metrics (such as time to solution and error at certain GMRES iterations) and go to 1.
#
#
# Scroll past the outputs to see some plots

# %%
from src_dir import Gauss_pdf_2D,resid


#Set the seed
np.random.seed(0)

# initialize lists that hold timing data
ML_GMRES_Time_list=[]

Err_list=[]
NonML_Err_List=[]

run_time_ML_list=[]
run_timeP1_ML_list=[]
run_timeP2_ML_list=[]

run_time_list=[]
GmresRunTimeOriginal=[]
SpeedUp=[]
trainTime_list=[]


# Set debug mode)prints more information to screen)
debug=True


# initalize lists that will hold all RHS and reisudals
blist=[]
bnormList=[]
reslist=[]
reslist_flat=[]
IterErrList=[]
NonML_Err_List_Full=[]
# Index of  Poisson problems solved
solIndx=0

for ProbIdx in range(n_steps):

    # Set RHS of Poisson problem
    xloc=np.random.uniform(-1,1)
    yloc=np.random.uniform(-1,1)
    sigma=0.2
    b=Gauss_pdf_2D(X,Y,xloc,yloc,sigma)
    # b=np.maximum(xloc*2*X*np.sin(ProbIdx),yloc*2*Y*np.cos(ProbIdx))




    # First GMRES call (solve up to e1 tolerance) with ML wrapper
    OutList1,run_time1_ML=MLGMRES(A, b, x0, e1, nmax_iter,ML_GMRES_Time_list,ProbIdx,restart,debug,blist,bnormList,reslist,Err_list,reslist_flat,solIndx,IterErrList)  # normalize b for optimal NN performance.
    Out=OutList1[0]
    ML_GMRES_Time_list=OutList1[1]
    trainTime_list.append(OutList1[2])
    blist=OutList1[3]
    reslist=OutList1[4]
    Err_list=OutList1[5]
    reslist_flat=OutList1[6]
    solIndx=OutList1[7]
    IterErrList=OutList1[8]
    bnormList=OutList1[9]

    # Collect ML assisted Run-times
    run_time_ML_list.append(run_time1_ML)
    


    # Direct GMRES call up to e1 tolerance
    NonML_Out1,run_time1=GMRES_timed(A, b, x0, e1, nmax_iter,restart, debug)  
    NonML_Err=resid(A, NonML_Out1, b)
    NonML_Err_List_Full.append(NonML_Err)
    NonML_Err_List.append(NonML_Err[5])
    GmresRunTimeOriginal.append(run_time1)

    # run-times
    run_time_list.append(run_time1)
    MLGMRES_GMRES_ONLY=sum(ML_GMRES_Time_list)
    SpeedUp.append(run_time1/ML_GMRES_Time_list[-1])
    

    print(ProbIdx)
    print("Speed up:", SpeedUp[-1])

run_time=sum(run_time_list)
run_time_ML=sum(run_time_ML_list)
trainTime_total=sum(trainTime_list)


print("Runtime of Non-decorated version is:",run_time)

print("Runtime of MLGMRES decorator is:",run_time_ML)

print("Runtime of MLGMRES (only GMRES time) is:",MLGMRES_GMRES_ONLY)

print("Runtime of training (backprop) is:",trainTime_total)
# Out:
#  Loss: 6.0063375713070855e-05
# ****************
# ****************
# Total Loss: 6.529621168738231e-05
# ****************
# ****************
# Total Loss: 5.5512835388071835e-05
# ****************
# ****************
# Total Loss: 5.884779238840565e-05
# ****************
# ****************
# Total Loss: 6.052853132132441e-05
# ****************
# ****************
# Total Loss: 5.939332186244428e-05
# ****************
# ****************
# Total Loss: 6.132470298325643e-05
# ****************
# ****************
# Total Loss: 6.323220441117883e-05
# ****************
# ****************
# Total Loss: 5.960208363831043e-05
# ****************
# ****************
# Total Loss: 5.6128930737031624e-05
# ****************
# ****************
# Total Loss: 6.284102710196748e-05
# ****************
# ****************
# Total Loss: 5.4054220527177677e-05
# ****************
# ****************
# Total Loss: 5.750821583205834e-05
# ****************
# ****************
# Total Loss: 6.119350291555747e-05
# ****************
# ****************
# Total Loss: 5.757425242336467e-05
# ****************
# ****************
# Total Loss: 6.210963329067454e-05
# ****************
# ****************
# Total Loss: 5.788578710053116e-05
# ****************
# ****************
# Total Loss: 5.8109442761633545e-05
# ****************
# ****************
# Total Loss: 5.8784415159607306e-05
# ****************
# ****************
# Total Loss: 5.475639773067087e-05
# ****************
# ****************
# Total Loss: 5.819733632961288e-05
# ****************
# ****************
# Total Loss: 5.8761575928656384e-05
# ****************
# ****************
# Total Loss: 5.707176387659274e-05
# ****************
# ****************
# Total Loss: 5.9077752666780725e-05
# ****************
# ****************
# Total Loss: 5.724644870497286e-05
# ****************
# ****************
# Total Loss: 5.828000939800404e-05
# ****************
# ****************
# Total Loss: 5.656190842273645e-05
# ****************
# ****************
# Total Loss: 5.784849781775847e-05
# ****************
# ****************
# Total Loss: 5.844610132044181e-05
# ****************
# ****************
# Total Loss: 5.6247226893901825e-05
# ****************
# ****************
# Total Loss: 5.795672404929064e-05
# ****************
# ****************
# Total Loss: 5.8609792176866904e-05
# ****************
# ****************
# Total Loss: 5.793067248305306e-05
# ****************
# ****************
# Total Loss: 6.861106521682814e-05
# ****************
# ****************
# Total Loss: 6.86218700138852e-05
# ****************
# ****************
# Total Loss: 6.0715734434779733e-05
# ****************
# ****************
# Total Loss: 5.770112693426199e-05
# ****************
# ****************
# Total Loss: 5.791964940726757e-05
# ****************
# ****************
# Total Loss: 6.457919516833499e-05
# ****************
# ****************
# Total Loss: 6.535513239214197e-05
# ****************
# ****************
# Total Loss: 5.9846432122867554e-05
# ****************
# ****************
# Total Loss: 6.0618775023613125e-05
# ****************
# ****************
# Total Loss: 6.239769572857767e-05
# ****************
# ****************
# Total Loss: 6.467918865382671e-05
# ****************
# ****************
# Total Loss: 7.161885150708258e-05
# ****************
# ****************
# Total Loss: 5.621483796858229e-05
# ****************
# ****************
# Total Loss: 7.879821350798011e-05
# ****************
# ****************
# Total Loss: 6.306668365141377e-05
# ****************
# ****************
# Total Loss: 6.322406261460856e-05
# ****************
# ****************
# Total Loss: 5.82298707740847e-05
# ****************
# ****************
# Total Loss: 6.923817272763699e-05
# ****************
# ****************
# Total Loss: 5.814020914840512e-05
# ****************
# ****************
# Total Loss: 6.797698006266728e-05
# ****************
# ****************
# Total Loss: 5.980256537441164e-05
# ****************
# ****************
# Total Loss: 6.30645954515785e-05
# ****************
# ****************
# Total Loss: 5.812467497889884e-05
# ****************
# ****************
# Total Loss: 6.022364686941728e-05
# ****************
# ****************
# Total Loss: 7.034983718767762e-05
# ****************
# ****************
# Total Loss: 6.208565173437819e-05
# ****************
# ****************
# Total Loss: 6.423707964131609e-05
# ****************
# ****************
# Total Loss: 6.495979323517531e-05
# ****************
# ****************
# Total Loss: 6.61519225104712e-05
# ****************
# ****************
# Total Loss: 6.758013478247449e-05
# ****************
# ****************
# Total Loss: 6.327356095425785e-05
# ****************
# ****************
# Total Loss: 6.573508289875463e-05
# ****************
# ****************
# Total Loss: 6.0485865105874836e-05
# ****************
# ****************
# Total Loss: 6.414978270186111e-05
# ****************
# ****************
# Total Loss: 6.33235540590249e-05
# ****************
# ****************
# Total Loss: 7.109177386155352e-05
# ****************
# ****************
# Total Loss: 6.682882667519152e-05
# ****************
# ****************
# Total Loss: 6.187703547766432e-05
# ****************
# ****************
# Total Loss: 6.97747673257254e-05
# ****************
# ****************
# Total Loss: 5.932636122452095e-05
# ****************
# ****************
# Total Loss: 6.302071415120736e-05
# ****************
# ****************
# Total Loss: 5.9994337789248675e-05
# ****************
# ****************
# Total Loss: 6.410582864191383e-05
# ****************
# ****************
# Total Loss: 6.0702397604472935e-05
# ****************
# ****************
# Total Loss: 6.226106052054092e-05
# ****************
# ****************
# Total Loss: 6.0274640418356284e-05
# ****************
# ****************
# Total Loss: 5.704802606487647e-05
# ****************
# ****************
# Total Loss: 5.7202978496206924e-05
# ****************
# ****************
# Total Loss: 6.0583162849070504e-05
# ****************
# ****************
# Total Loss: 6.161721830721945e-05
# ****************
# ****************
# Total Loss: 6.214226596057415e-05
# ****************
# ****************
# Total Loss: 5.641131429001689e-05
# ****************
# ****************
# Total Loss: 5.399788642534986e-05
# ****************
# ****************
# Total Loss: 6.558417953783646e-05
# ****************
# ****************
# Total Loss: 6.307494186330587e-05
# ****************
# ****************
# Total Loss: 7.335056579904631e-05
# ****************
# ****************
# Total Loss: 6.335000944091007e-05
# ****************
# ****************
# Total Loss: 6.935728742973879e-05
# ****************
# ****************
# Total Loss: 6.246064003789797e-05
# ****************
# ****************
# Total Loss: 6.294235936366022e-05
# ****************
# ****************
# Total Loss: 7.508488488383591e-05
# ****************
# ****************
# Total Loss: 6.0769758420065045e-05
# ****************
# ****************
# Total Loss: 7.103310781531036e-05
# ****************
# ****************
# Total Loss: 7.123612886061892e-05
# ****************
# ****************
# Total Loss: 6.540419417433441e-05
# ****************
# ****************
# Total Loss: 6.133830174803734e-05
# ****************
# ****************
# Total Loss: 6.279990338953212e-05
# ****************
# ****************
# Total Loss: 5.7894336350727826e-05
# ****************
# ****************
# Total Loss: 6.9301066105254e-05
# ****************
# ****************
# Total Loss: 6.145054794615135e-05
# ****************
# ****************
# Total Loss: 6.570573168573901e-05
# ****************
# ****************
# Total Loss: 6.166993989609182e-05
# ****************
# ****************
# Total Loss: 6.705382111249492e-05
# ****************
# ****************
# Total Loss: 6.211696017999202e-05
# ****************
# ****************
# Total Loss: 7.273160736076534e-05
# ****************
# ****************
# Total Loss: 5.7546050811652094e-05
# ****************
# ****************
# Total Loss: 6.182945799082518e-05
# ****************
# ****************
# Total Loss: 6.650768773397431e-05
# ****************
# ****************
# Total Loss: 6.051737000234425e-05
# ****************
# ****************
# Total Loss: 7.353135151788592e-05
# ****************
# ****************
# Total Loss: 6.260268855839968e-05
# ****************
# ****************
# Total Loss: 6.311323522822931e-05
# ****************
# ****************
# Total Loss: 5.792102820123546e-05
# ****************
# ****************
# Total Loss: 6.022836168995127e-05
# ****************
# ****************
# Total Loss: 6.112903793109581e-05
# ****************
# ****************
# Total Loss: 5.866435822099447e-05
# ****************
# ****************
# Total Loss: 6.610205309698358e-05
# ****************
# ****************
# Total Loss: 5.952907304163091e-05
# ****************
# ****************
# Total Loss: 6.331632903311402e-05
# ****************
# ****************
# Total Loss: 5.539961057365872e-05
# ****************
# ****************
# Total Loss: 6.438679702114314e-05
# ****************
# ****************
# Total Loss: 5.4987005569273606e-05
# ****************
# ****************
# Total Loss: 6.825687160016969e-05
# ****************
# ****************
# Total Loss: 5.8920762967318296e-05
# ****************
# ****************
# Total Loss: 5.9875565057154745e-05
# ****************
# ****************
# Total Loss: 6.0455990023911e-05
# ****************
# ****************
# Total Loss: 5.810134462080896e-05
# ****************
# ****************
# Total Loss: 5.985094321658835e-05
# ****************
# ****************
# Total Loss: 5.672487532137893e-05
# ****************
# ****************
# Total Loss: 6.239964568521827e-05
# ****************
# ****************
# Total Loss: 6.067127105779946e-05
# ****************
# ****************
# Total Loss: 5.456692451843992e-05
# ****************
# ****************
# Total Loss: 5.554523158934899e-05
# ****************
# ****************
# Total Loss: 6.528812809847295e-05
# ****************
# ****************
# Total Loss: 6.586909148609266e-05
# ****************
# ****************
# Total Loss: 6.002709051244892e-05
# ****************
# ****************
# Total Loss: 5.7482968259137124e-05
# ****************
# ****************
# Total Loss: 5.911222251597792e-05
# ****************
# ****************
# Total Loss: 5.865886851097457e-05
# ****************
# ****************
# Total Loss: 6.210789433680475e-05
# ****************
# ****************
# Total Loss: 5.948159014224075e-05
# ****************
# ****************
# Total Loss: 6.920637679286301e-05
# ****************
# ****************
# Total Loss: 6.33142699371092e-05
# ****************
# ****************
# Total Loss: 5.969216726953164e-05
# ****************
# ****************
# Total Loss: 7.134925544960424e-05
# ****************
# ****************
# Total Loss: 6.21446015429683e-05
# ****************
# ****************
# Total Loss: 8.867527503753081e-05
# ****************
# ****************
# Total Loss: 8.469842578051612e-05
# ****************
# ****************
# Total Loss: 6.494327681139112e-05
# ****************
# ****************
# Total Loss: 8.13479273347184e-05
# ****************
# ****************
# Total Loss: 8.009045268408954e-05
# ****************
# ****************
# Total Loss: 6.59934084978886e-05
# ****************
# ****************
# Total Loss: 7.126966374926269e-05
# ****************
# ****************
# Total Loss: 6.686844426440075e-05
# ****************
# ****************
# Total Loss: 6.858869164716452e-05
# ****************
# ****************
# Total Loss: 9.33858536882326e-05
# ****************
# ****************
# Total Loss: 7.561592065030709e-05
# ****************
# ****************
# Total Loss: 6.60643054288812e-05
# ****************
# ****************
# Total Loss: 7.036956230876967e-05
# ****************
# ****************
# Total Loss: 6.542657501995564e-05
# ****************
# ****************
# Total Loss: 9.000916907098144e-05
# ****************
# ****************
# Total Loss: 6.183765799505636e-05
# ****************
# ****************
# Total Loss: 6.799715629313141e-05
# ****************
# ****************
# Total Loss: 6.605215457966551e-05
# ****************
# ****************
# Total Loss: 7.991346501512453e-05
# ****************
# ****************
# Total Loss: 8.471214823657647e-05
# ****************
# ****************
# Total Loss: 7.537939382018521e-05
# ****************
# ****************
# Total Loss: 6.4163061324507e-05
# ****************
# ****************
# Total Loss: 9.10251255845651e-05
# ****************
# ****************
# Total Loss: 7.318893040064722e-05
# ****************
# ****************
# Total Loss: 6.46546614007093e-05
# ****************
# ****************
# Total Loss: 8.6052248661872e-05
# ****************
# ****************
# Total Loss: 7.17689108569175e-05
# ****************
# ****************
# Total Loss: 7.087757694534957e-05
# ****************
# ****************
# Total Loss: 6.664392276434228e-05
# ****************
# ****************
# Total Loss: 6.268927245400846e-05
# ****************
# ****************
# Total Loss: 7.349356746999547e-05
# ****************
# ****************
# Total Loss: 6.487651262432337e-05
# ****************
# ****************
# Total Loss: 6.610053969779983e-05
# ****************
# ****************
# Total Loss: 6.699043296976015e-05
# ****************
# ****************
# Total Loss: 6.912719254614785e-05
# ****************
# ****************
# Total Loss: 7.339814328588545e-05
# ****************
# ****************
# Total Loss: 5.982543370919302e-05
# ****************
# ****************
# Total Loss: 5.7945624575950205e-05
# ****************
# ****************
# Total Loss: 6.819038389949128e-05
# ****************
# ****************
# Total Loss: 7.787461800035089e-05
# ****************
# ****************
# Total Loss: 6.598683830816299e-05
# ****************
# ****************
# Total Loss: 6.8725596065633e-05
# ****************
# ****************
# Total Loss: 6.405495514627546e-05
# ****************
# ****************
# Total Loss: 5.847796637681313e-05
# ****************
# ****************
# Total Loss: 6.433406088035554e-05
# ****************
# ****************
# Total Loss: 6.224948447197676e-05
# ****************
# ****************
# Total Loss: 8.107945905067027e-05
# ****************
# ****************
# Total Loss: 6.9882495154161e-05
# ****************
# ****************
# Total Loss: 6.597334140678868e-05
# ****************
# ****************
# Total Loss: 6.196414324222133e-05
# ****************
# ****************
# Total Loss: 5.982866059639491e-05
# ****************
# ****************
# Total Loss: 7.332462701015174e-05
# ****************
# ****************
# Total Loss: 6.817432586103678e-05
# ****************
# ****************
# Total Loss: 6.574417056981474e-05
# ****************
# ****************
# Total Loss: 6.449809006880969e-05
# ****************
# ****************
# Total Loss: 6.599159678444266e-05
# ****************
# ****************
# Total Loss: 6.446812039939687e-05
# ****************
# ****************
# Total Loss: 7.228161121020094e-05
# ****************
# ****************
# Total Loss: 6.005604882375337e-05
# ****************
# ****************
# Total Loss: 7.309331704163924e-05
# ****************
# ****************
# Total Loss: 9.127504745265469e-05
# ****************
# ****************
# Total Loss: 8.631419768789783e-05
# ****************
# ****************
# Total Loss: 7.957056368468329e-05
# ****************
# ****************
# Total Loss: 6.694154581055045e-05
# ****************
# ****************
# Total Loss: 8.192113455152139e-05
# ****************
# ****************
# Total Loss: 7.118798384908587e-05
# ****************
# ****************
# Total Loss: 7.441033085342497e-05
# ****************
# ****************
# Total Loss: 8.88551221578382e-05
# ****************
# ****************
# Total Loss: 8.805161633063108e-05
# ****************
# ****************
# Total Loss: 6.778095848858356e-05
# ****************
# ****************
# Total Loss: 8.429527224507183e-05
# ****************
# ****************
# Total Loss: 8.886298746801913e-05
# ****************
# ****************
# Total Loss: 6.047865463187918e-05
# ****************
# ****************
# Total Loss: 8.39064596220851e-05
# ****************
# ****************
# Total Loss: 6.727879372192547e-05
# ****************
# ****************
# Total Loss: 7.96900931163691e-05
# ****************
# ****************
# Total Loss: 6.794455839553848e-05
# ****************
# ****************
# Total Loss: 6.784043944207951e-05
# ****************
# ****************
# Total Loss: 6.870093784527853e-05
# ****************
# ****************
# Total Loss: 6.735605711583048e-05
# ****************
# ****************
# Total Loss: 7.405178621411324e-05
# ****************
# ****************
# Total Loss: 6.065876004868187e-05
# ****************
# ****************
# Total Loss: 6.042546374374069e-05
# ****************
# ****************
# Total Loss: 5.9909139963565394e-05
# ****************
# ****************
# Total Loss: 5.777366095571779e-05
# ****************
# ****************
# Total Loss: 6.952318653929979e-05
# ****************
# ****************
# Total Loss: 6.362234125845134e-05
# ****************
# ****************
# Total Loss: 5.598560892394744e-05
# ****************
# ****************
# Total Loss: 5.7089495385298505e-05
# ****************
# ****************
# Total Loss: 6.564807699760422e-05
# ****************
# ****************
# Total Loss: 6.296640640357509e-05
# ****************
# ****************
# Total Loss: 6.171638960950077e-05
# ****************
# ****************
# Total Loss: 5.754944868385792e-05
# ****************
# ****************
# Total Loss: 6.593682337552309e-05
# ****************
# ****************
# Total Loss: 6.49604553473182e-05
# ****************
# ****************
# Final Total Loss: 5.74867008253932e-05
# ****************
# parameters 3391
# 4979
# Speed up: 1.3883582210430288
# size 8
# 4.679065863324957 6.213899013746545
# 0.3942472019989509 0.3653990130803868 0.26277656242671155 0.3208202072109249
# 4980
# Speed up: 1.3814989865208787
# size 8
# 5.587237285869538 6.213899013746545
# 0.39585122800053796 0.3673276040003111 0.3009429618233741 0.3208848182671231
# 4981
# Speed up: 1.4541890899457794
# size 8
# 5.756811401778032 6.213899013746545
# 0.3575569929998892 0.3707048524802667 0.325452258476353 0.31833492644692724
# 4982
# Speed up: 1.6010330834125472
# size 8
# 3.077812722393063 6.213899013746545
# 0.41446538399941346 0.37186132744027417 0.24682801930747025 0.31875324368237445
# 4983
# Speed up: 1.3042777946477369
# size 8
# 3.1106176851584273 6.213899013746545
# 0.3468584849997569 0.3746409108802618 0.3524597336889415 0.31641134193148673
# 4984
# Speed up: 1.4983919219991209
# size 8
# 3.7525093016399076 6.213899013746545
# 0.342951210001047 0.37568115196023427 0.299932314103055 0.31878281627333854
# 4985
# Speed up: 1.569257804917991
# size 8
# 6.535653631900949 6.213899013746545
# 0.3717534879997402 0.37507470220029065 0.2963811596007827 0.31867369621423863
# 4986
# Speed up: 1.5315744824994413
# size 8
# 3.010784570974199 6.213899013746545
# 0.3838285600013478 0.3734172710402345 0.2818553429438789 0.312627286242965
# 4987
# Speed up: 1.4071819043354077
# size 8
# 7.440642255509778 6.213899013746545
# 0.40302186100052495 0.3734786329202325 0.3901796971582115 0.3117591394269858
# 4988
# Speed up: 1.4849661492682662
# size 8
# 8.526390998249518 6.213899013746545
# 0.34626360299989756 0.37478048360018873 0.3197190019582426 0.31263276638820753
# 4989
# Speed up: 1.665720892997286
# size 8
# 5.758076318918338 6.213899013746545
# 0.3549560890005523 0.37444350576013674 0.3038780614602954 0.31050631704995907
# 4990
# Speed up: 1.5548830041285742
# size 8
# 7.342850178019765 6.213899013746545
# 0.4252085120006086 0.37263992160013004 0.3630652025786458 0.3109979110802417
# 4991
# Speed up: 1.3759377587409816
# size 8
# 7.0254886569437 6.213899013746545
# 0.3724086840011296 0.37402679264014294 0.34498843508497157 0.31400101838134264
# 4992
# Speed up: 1.5796801827483682
# size 8
# 8.42105644892585 6.213899013746545
# 0.39147890899948834 0.37579256304023145 0.30126008440469565 0.3162980325665533
# 4993
# Speed up: 1.4823476403466525
# size 8
# 3.799967755063494 6.213899013746545
# 0.2315247709993855 0.375189841440224 0.2430891410868456 0.3137519188097654
# 4994
# Speed up: 2.342777257307533
# size 8
# 7.625224688729539 6.213899013746545
# 0.34312051000051724 0.37084004156022277 0.32315561522633635 0.3137631838514165
# 4995
# Speed up: 1.7225674034993363
# size 8
# 8.628694026534564 6.213899013746545
# 0.37817755000105535 0.3694487665603083 0.30168657588231934 0.3152072397094856
# 4996
# Speed up: 1.5357358547553857
# size 8
# 7.489113435391616 6.213899013746545
# 0.38660646499920404 0.37000307668029564 0.32488068231263045 0.31557993942358925
# 4997
# Speed up: 1.5248581448347667
# size 8
# 7.401922413420325 6.213899013746545
# 0.3626301640015299 0.37807389212022824 0.2881537049463617 0.3187790690727535
# 4998
# Speed up: 1.6367064627215042
# size 8
# 3.9076547848202914 6.213899013746545
# 0.35613474500132725 0.37565195052025957 0.3034228988360132 0.31555415622389077
# 4999
# Speed up: 1.528952163871168
# Runtime of Non-decorated version is: 2850.7410082700094
# Runtime of MLGMRES decorator is: 4282.083642568978
# Runtime of MLGMRES (only GMRES time) is: 1904.2130509859962
# Runtime of training (backprop) is: 456.7982364749911

# %% [markdown]
# Below, the error for the 5th GMRES iteration for every "time-step"  is plotted. The gist is that we see neural network is learning to produce initial guesses that improve the error at this iteration as our simulation progresses.

# %%
import matplotlib.pyplot as pp
from src_dir import moving_average

AVG=np.zeros((n_steps,1))
count=np.arange(0,n_steps)

Err_Array=np.asarray(NonML_Err_List)
count=np.arange(0,n_steps)
for j in range(0,n_steps):
    AVG[j]=moving_average(np.asarray(Err_Array[:j]),j)

Err_Array_ML=np.asarray(Err_list)
AVGML=np.zeros((n_steps,1))
for j in range(0,n_steps):
    AVGML[j]=moving_average(np.asarray(Err_Array_ML[:j]),j)    


pp.plot(count,Err_Array_ML,'.b',label='MLGMRES error')
pp.plot(count[10:-1],AVGML[10:-1],'k',label='Average MLGMRES error')
pp.plot(count,Err_Array,'.r',label='GMRES error')
pp.plot(count[10:-1],AVG[10:-1],'g',label='Average GMRES error')

pp.xlabel('$i$')
pp.ylabel('$||r_2||_2$')
pp.title('Error as a function of $i$-th iteration')
pp.legend(loc='best')
pp.yscale("log")

# %% [markdown]
# Below, the time-to-solution for every "time-step"  is plotted.
# Here, we see the neural network is learning to produce initial guesses that improve the overall time-to-solution for every iteration as our simulation progresses.

# %%
GmresRunTimeOriginal_AVG=np.zeros((n_steps,1))
ML_GMRES_Time_AVG=np.zeros((n_steps,1))


for j in range(0,n_steps):
    GmresRunTimeOriginal_AVG[j]=moving_average(np.asarray(GmresRunTimeOriginal[:j]),j)

for j in range(0,n_steps):
    ML_GMRES_Time_AVG[j]=moving_average(np.asarray(ML_GMRES_Time_list[:j]),j)
    
    
pp.plot(ML_GMRES_Time_list,'.b',label='MLGMRES')
pp.plot(GmresRunTimeOriginal,'.r', label='GMRES')
pp.plot(count[10:-1],GmresRunTimeOriginal_AVG[10:-1],'g', label='GMRES Average')
pp.plot(count[10:-1],ML_GMRES_Time_AVG[10:-1],'k', label='MLGMRES Average')

pp.ylabel('Time (s)')
pp.xlabel('i')
pp.title('GMRES run time')
pp.legend(loc='best')
# pp.ylim(0.025,0.15)
pp.yscale("log")

# %% [markdown]
# In the figure below, the GMRES iterations for a single linear problem is plotted. This figures is particularly useful for understanding why we are getting a speed-up at all. In a nut-shell, we get a speed up because the NN-provided intial guess temporarily improves the rate of convergence of GMRES

# %%
RHSIndex=-1
pp.semilogy(NonML_Err_List_Full[RHSIndex],'.r',label='GMRES')
pp.semilogy(IterErrList[RHSIndex],'.b',label='MLGMRES ')
pp.legend(loc='best')
pp.xlabel('GMRES iterations')
pp.ylabel('$||r||_2$')
pp.title('Convergence of Algorithim for Final Linear Problem')
# Out:
# Text(0.5, 1.0, 'Convergence of Algorithim for Final Linear Problem')

# %% [markdown]
# The ratio of GMRES/MLGMRES time-to-solutions are plotted below for the first $e_1$ tolerance.
# It should be noted that our methodology wraps around the direct GMRES solver,
# so the exact same solver is used in both approaches, and only differ by what initial condition
# (or effectively left-preconditioner) is applied.

# %%
GMRESAVG=GmresRunTimeOriginal_AVG[10:-1]
MLGMRESAVG=ML_GMRES_Time_AVG[10:-1]
Ratio=np.divide(GMRESAVG,MLGMRESAVG)

pp.plot(Ratio,'.b')
pp.xlabel('i')
pp.ylabel('GMRES/MLGMRES')
pp.title("NN Speed Up ")
# Out:
# Text(0.5, 1.0, 'NN Speed Up ')
